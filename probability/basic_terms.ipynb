% %% [markdown]
% ### Basic terms in probability
%
% #### Random experiment
%
% A situation that does not depend on any other experiments. For example, a coin flip. This experiment can involve a fair or loaded coin.
%
% Any process which is subject to variability.
%
% #### Trial
%
% A moment in the experiment. For example, if the random experiment says to flip two coins then a trial is to flip both coins and record the results.
%
% #### Outcome
%
% The result of a single trial. Might be more than one occurence.
%
% #### Simple event
%
% If a trial requires you to flip two coins, then when you flip either coin this will give you a simple event. A head or tail might occur.
%
% #### Compound event
%
% If a trial requires more than one simple event then this is also called a compound event.
%
% #### Sample space
%
% This is the set of all possible outcomes for an experiment. This is denoted by $ \Omega $.
%
% If the experiment is to flip a coin then $ \Omega = \{H, T\} $
%
% If the experiment is to flip two coins then $ \Omega = \{HH, HT, TH, TT\} $
%
% If the experiment is to roll 1d6 then the sample space is $ \Omega = \{1,2,3,4,5,6\} $
%
% #### Event
%
% You can use this term to refer to either a simple or compound event.
%
% If $ \Omega = \{HH,HT,TH,TT\} $
%
% And a trial is to flip two coins then the event might be that the first coin is $ H $.
%
% Then the compound event is $ E = \{HH, HT \} $
%
% The event might be that at least one coin is $ T $
%
% Then the compound event is $ E = \{HT, TH, TT \} $
%
% #### Probability of x occuring, single random experiment
%
% The probability of something is the chance of that occuring, or a simple event, divided by all possible outcomes.
%
% Eg.
%
% Probability of rolling a 5 with 1d6.
%
% $ \frac{1}{6} $
%
% Probability of rolling a 5 or 6 with 1d6.
%
% $ \frac{1}{6} + \frac{1}{6} = \frac{2}{6} = \frac{1}{3} $
%
% Probability of drawing a heart from a deck of cards.
%
% $ \frac{13}{52} = \frac{1}{4} $
%
% Think of "or" like plus and "and" like multiplication
%
% #### Odds
%
% Consider a single random experiment.
%
% The odds is the probability of an event occuring divided by the probability of it not occuring.
%
% Eg: the odds of rolling a 6 with 1d6.
%
% $ \frac{1}{6} $
%
% Or not:
%
% $ \frac{5}{6} $
%
% The odds:
%
% $ \frac{1/6}{5/6} = \frac{1}{6} * \frac{6}{5} = \frac{6}{30} = 1:5 $
%
% #### Odds ratio
%
% Consider two random experiments, with different probabilities and therefore different odds also.
%
% Rolling a 1 with a fair 1d6:
%
% odds = $ 1/6 : 5/6 = 1:5 = 0.2 $
%
% Flipping a head with a loaded coin:
%
% odds = $ .7 : .3 = 2.\dot 3 $
%
% odds ratio = $ \frac{2. \dot 3}{0.2} = 11.\dot 6 $
%
% This means that flipping a head with the example loaded coin is $ 11. \dot 6$ times greater than the odds of rolling 1 with a 1d6.
%
% #### Unconditional probability
%
% $ P(A) $ the probability of $ A $ regardless of any other information. If the total count is 100 then $ P(A) = A/100 $
%
% #### Conditional probability
%
% $ P(A|B) $ the probability of $ A $ given $ B $, see the relevant notebook.
%
% #### Symmetry
%
% If a random experiment has a finite number of possible outcomes, and we cannot say that one is more likely than the other, then the probability of each outcome is:
%
% $ P(outcome) = \frac{1}{n} $
%
% Where $ n $ is the number of possible outcomes.
%
% EG: if we have a symmetric die, then:
%
% $ P(outcome) = \frac{1}{6} $
%
% #### Prior probability
%
% DEFINE
%
% #### Subjective assignment
%
% The process of assigning subjective prior probability
