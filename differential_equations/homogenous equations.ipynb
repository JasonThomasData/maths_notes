% %% [markdown]
% ### Homogenous equations
%
% #### First order
%
% A function is homogenous if it can be written:
%
% $ f(x, y)dy = g(x, y)dx $
%
% Where both functions are of the same degree.
%
% The form implies that it is not seperable.
%
% If a differential equation is not seperable and not solveable in a linear form then try this.
%
% $ \frac{dy}{dx} = f(x,y) $
%
% Then make it look like
%
% $ \frac{dy}{dx} = Q(\frac{y}{x}) $
%
% This new function has a single term:
%
% $ v = \frac{y}{x} $
%
% Then:
%
% $ y = x\cdot v $
%
% We also need to know:
%
% $ \frac{dy}{dx} = \frac{d}{dx} (x \cdot v) $, as the product rule
%
% $ \frac{dy}{dx} = x \cdot \frac{dv}{dx} + 1 \cdot v  $
%
% Substitute those into the equation, and simplify.
%
% $ \frac{dy}{dx} = Q(\frac{y}{x}) $
%
% To:
%
% $ x \cdot \frac{dv}{dx} + 1 \cdot v  = Q(v) $
%
% $ x \cdot \frac{dv}{dx} = Q(v) - v $
%
% $ \frac{1}{x} \cdot \frac{dx}{dv} = \frac{1}{Q(v) - v} $
%
% $ \frac{1}{x} dx = \frac{1}{Q(v) - v} dv $
%
% And so the DE has become seperable.
%
% #### Example
%
% $ (xy + x^2 + y^2)dx - x^2 \cdot dy = 0 $
%
% $ x^2 \cdot dy = (xy + x^2 + y^2) dx $
%
% $ x^2 \cdot \frac{dy}{dx} = xy + x^2 + y^2 $
%
% $ \frac{dy}{dx} = \frac{xy + x^2 + y^2}{x^2} $
%
% $ \frac{dy}{dx} = \frac{y}{x} + 1 + \left(\frac{y}{x}\right)^2 $
%
% $ v = \frac{y}{x} $
%
% $ y = vx $
%
% $ \frac{dy}{dx} = v\cdot 1 + \frac{dv}{dx} x $
%
% Then substitute it all into here:
%
% $ \frac{dy}{dx} = \frac{y}{x} + 1 + \left(\frac{y}{x}\right)^2 $
%
% $ v\cdot 1 + \frac{dv}{dx} x = v + 1 + (v)^2 $
%
% $ \frac{dv}{dx} x = 1 + (v)^2 $
%
% $ \frac{1}{x} \frac{dx}{dv} = \frac{1}{1 + (v)^2} $
%
% $ \frac{1}{x} dx = \frac{1}{1 + (v)^2} dv $
%
% It's now seperable, and has been seperated.
%
% Solve the DE and then substitute back in the value of $ v $, which will be $ \frac{y}{x} $
