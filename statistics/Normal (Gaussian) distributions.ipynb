# %% [markdown]
# ### Normal/Guassian family of distributions
#
# Q: can it be discrete?
#
# #### PDF:
#
# $ X \sim N(\mu, \sigma^2) $
#
# Above, allows different parameters to derive different distributions and this is why we say it's "a family"
#
# $ \frac{1}{\sigma \sqrt{2 \pi}} e^{-\frac{(x-\mu)^2}{2\sigma^2}} $
#
# But we often care about the Standard Normal Distribution:
#
# $ Z \sim N(0, 1) $
#
# $ \frac{1}{\sigma \sqrt{2 \pi}} e^{-\frac{1}{2}z^2} $
#
# Note, that to find the area under this curve we must use numerical techniques. I'm unsure if this is because the integral doesn't exist or perhaps it's crazy hard.
#
# There is a useful video that explains the existence of $ e, \pi $ and some of the intuition behind the distribution - https://www.youtube.com/watch?v=cy8r7WSuT1I
#
#
# #### Converting to a Normal to the Standardised Normal Distribution
#
# $ X \sim N(\mu, \sigma^2) $
#
# $ Z \sim N(0, 1) $
#
# $ Z = \frac{X - \mu}{\sigma} $
#
# Notice that the distribution takes $ \sigma^2 $ (variance) as a parameter but the conversion takes $ \sigma $ (standard deviation).
#
# _Conversion example_
#
# $ X \sim N(80,100) $
#
# $ P(X < 100) = P \left(Z < \frac{100-80}{10} \right) $
#
# Where the denominator is the root of the distribution parameter.
#
# Then you can compare this to a Z table.
#
# #### Example finding probability
#
# Suppose $ W \sim N(25, 3.5^2) $, which means $ W $ is a r.v. from the Normal Distribution with a mean of $ 25 $ and standard deviation of $ 3.5 $, which when squared becomes the population variance.
#
# ##### Find probability $ W > 20 $
#
# $ P(W > 20) $
#
# $ P\left(Z > \frac{W - \mu}{\sigma^2} \right) $
#
# $ P\left(Z > \frac{20 - 25}{3.5} \right) $
#
# $ P(Z > -1.43 ) = (1 - P(Z < -1.43)) $
#
# So you look the above probability up in a Z table.
#
# ##### Find probability $ W $ is within 1.5 standard deviations of the mean
#
# $ P(|W - \mu| < 1.5\sigma ) $
#
# $ P(\frac{|W - \mu|}{\sigma} < 1.5 ) $
#
# $ P(|Z| < 1.5 ) $
#
# $ P(Z < 1.5 ) - P(Z < -1.5) $
#
# Look these up in a Z table

# %% [markdown]
# ### Bivariate Normal
#
# I haven't had time to summarise this. It's midway in module3iib lecure vid ~15:00
#
# It says how to
#
# $ E(X|y), Var(X|y), E(Y|x), Var(Y|x) $
#
# If there is no correlation then $ \rho = 0 $
#
# Then: $ f(x, y) = f(x)f(y) $
#
# #### Bivariate normal, expected value and standard deviation
#
# $ E(X|y) = \mu_X + \frac{\rho \sigma_X}{\sigma_Y}(Y - \mu_y) $
#
# $ \sigma_{X|y} = \sqrt{ \sigma_x^2(1 - \rho^2) } $

# %% [markdown]
# #### A r.v. from an unknown distribution is approximately normal
#
# Suppose we have a r.v. $ X $ but it's an unknown distribution.
#
# It has mean $ \mu $ and variance $ \sigma^2 = 0.04 $ and sample size $ n = 36 $.
#
# What is the probability that the estimation error is $ < 0.1 $
#
# I think this means that the estimation error is $ \bar X - \mu $, as in the difference between the sample statistic and the population parameter.
#
# Since $ n > 30 $ then we can say it will be approximately normal (see the central limit theorem).
#
# $ \bar X \sim \left(\mu, \frac{\sigma^2}{36} \right) $
#
# $ P(|\bar X - \mu| < 0.01) = P \left(\frac{|\bar X - \mu|}{\sigma} < \frac{0.01}{\sigma} \right) $
#
# Variance was defined as $ \frac{\sigma^2}{n} $ so that means:
#
# $ \sigma = \sqrt{\frac{\sigma^2}{36}} $
#
# $ P(|\bar X - \mu| < 0.01) = P \left(|Z| < \frac{0.01}{\sqrt{\sigma^2 / 36 }} \right) $
#
# $ P(Z < 0.3) - P(Z < -0.3) $
#
# Look these up in the Z table.
