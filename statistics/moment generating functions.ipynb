# %% [markdown]
# ### Moment generating functions
#
# $ M_X(t) = E(e^{tX}) $
#
# This is a function that lies in an interval $ -h \le t \le h $. Otherwise no mgf exists.
#
# $ E(X^n) = M_X^{(n)} $
#
# Example:
#
# $ E(X) = M_X^{(1)} $
#
# $ E(X^2) = M_X^{(2)} $
#
# #### Discrete r.v.
#
# From a given pmf $ p(x) $
#
# The mgf is:
#
# $ \sum_x e^{tx} p(x) $
#
# #### Continuous r.v.
#
# From a given pdf $ f(x) $
#
# The mgf is:
#
# $ \int_{-\infty}^\infty e^{tx} f(x) dx $
#
# #### Relation to the Taylor Series Expansion of $ e^x $
#
# The Taylor Series Expansion of $ e^x $ is:
#
# $ e^x = \frac{x^0}{0!} + \frac{x^1}{1!} + \frac{x^2}{2!} + ... + \frac{x^n}{n!} $
#
# Then this has the same form (using the Poisson Distribution):
#
# $ e^{\lambda e^t} = \frac{(\lambda e^t)^0}{0!} + \frac{(\lambda e^t)^1}{1!} + \frac{(\lambda e^t)^2}{2!} + ... + \frac{(\lambda e^t)^n}{n!} $
#
# Then what you want to do is treat $ \lambda e^t $ as $ e $
#
# #### Example, using Poisson Distribution
#
# The Poisson Distribution pmf is given by:
#
# $ p(x) = e^{-\lambda}\frac{\lambda^x}{X!} , x = 0,1,2,... $
#
# $ M_X(t) = \sum_\limits{x \ge 0} e^{-\lambda}\frac{\lambda^x}{X!} e^{tx} $
#
# Then
#
# $ M_X(t) = \sum_\limits{x \ge 0} e^{-\lambda}\frac{\lambda^x e^{tx}}{X!}  $
#
# $ M_X(t) = \sum_\limits{x \ge 0} e^{-\lambda}\frac{(\lambda e^{t})^x}{X!}  $
#
# The Taylor Series Expansion is:
#
# $ e^{\lambda e^t} = \frac{(\lambda e^t)^0}{0!} + \frac{(\lambda e^t)^1}{1!} + \frac{(\lambda e^t)^2}{2!} + ... + \frac{(\lambda e^t)^n}{n!} $
#
# Since $ e^{-\lambda} $ is a constant term then:
#
# $ M_X(t) = e^{-\lambda} e^{\lambda e^t} $
#
# $ M_X(t) = e^{-\lambda + \lambda e^t} $
#
# $ M_X(t) = e^{-\lambda(1 - e^t)} $
#
# With this simplified function we can find its first moment as the first derivative and the second moment as the second derivative.
#
# $ M_x^{(1)}(t) = \lambda e^t e^{-\lambda(1 - e^t)} $
#
# And the second derivative will use the Product Rule:
#
# $ M_x^{(2)}(t) = \lambda e^t \cdot e^{-\lambda(1 - e^t)} + \lambda e^t \cdot \lambda e^t e^{-\lambda(1 - e^t)}  $
#
# $ M_x^{(2)}(t) = \lambda e^t \cdot e^{-\lambda(1 - e^t)}(1 + \lambda e^t )$
#
# To actually find the moment, use $ t=0 $
#
# $ E(X^1) = M_x^{(1)}(0) = \lambda e^0 e^{-\lambda(1 - e^0)} = \lambda $
#
# $ E(X^2) = M_x^{(2)}(0) = \lambda e^t \cdot e^{-\lambda(1 - e^t)}(1 + \lambda e^t ) = \lambda(1 + \lambda) $
#
# #### Mean and variance
#
# The first moment, $ E(X^1) $ is the expected value aka mean.
#
# We find the variance of any pmf/pdf by using the second moment:
#
# $ E(X^2) - E(X)^2 $
